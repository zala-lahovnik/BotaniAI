# %% [markdown]
# # Import libraries

# %%
# !pip install tensorflow==2.8
# !pip install tensorflowjs
# !pip install numpy==1.21
# !pip install protobuf==3.20.*
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn

# %%
import pathlib
from pathlib import Path
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, GlobalAveragePooling2D
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay, f1_score, recall_score, precision_score, accuracy_score
from tensorflow.keras.utils import set_random_seed
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd

# %%
import tensorflowjs as tfjs

# %% [markdown]
# # Setting a seed
# Setting a seed so we can guarantee the same results no matter how many times we run the script

# %%
seed = 1605
np.random.seed(seed)
set_random_seed(seed)

# %% [markdown]
# # Setting the image directory

# %%
train_path = pathlib.Path("./data/train")
val_path = pathlib.Path('./data/val')
test_path = pathlib.Path('./data/test')

train_data = list(train_path.glob('*/*.jpeg'))

# %%
subpath = list(train_path.glob('*'))
species = []
boxplot_data = []

for i in range (0, len(subpath)):
    species.append(subpath[i].name)
    boxplot_data.append([subpath[i].name, len(os.listdir(subpath[i]))])

species.sort()

# %%
no_of_files = pd.DataFrame(columns=['Species', 'No of files'], data=boxplot_data)
list_of_species = []

for index, row in no_of_files.iterrows():
    if row['No of files'] >= 1000:
        list_of_species.append(row['Species'])
        
list_of_species   
len(list_of_species)
# Out:
# 65

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plot_species = no_of_files['Species']
plot_numbers = no_of_files['No of files']
ax.bar(plot_species,plot_numbers)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Setting image height and width

# %%
image_size = (150, 150) # (height, width)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    seed=1337,
    image_size=image_size
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_path,
    seed=1337,
    image_size=image_size
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_path,
    seed=1337,
    image_size=image_size
)
# Out:
# Found 157722 files belonging to 65 classes.
# Found 19759 files belonging to 65 classes.
# Found 19753 files belonging to 65 classes.

# %% [markdown]
# # Setting the model

# %%
model = Sequential()

# adding layers
model.add(Conv2D(96, (3, 3), input_shape=(image_size[0], image_size[1], 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None))
model.add(Conv2D(16, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu'))
model.add(Conv2D(64, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='valid'))
model.add(Conv2D(64, (3, 3), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None))
model.add(Conv2D(32, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu'))
model.add(Conv2D(128, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='valid'))
model.add(Conv2D(128, (3, 3), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None))
model.add(Conv2D(48, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu'))
model.add(Conv2D(192, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='valid'))
model.add(Conv2D(192, (3, 3), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None))
model.add(Conv2D(64, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu'))
model.add(Conv2D(256, (1, 1), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='valid'))
model.add(Conv2D(256, (3, 3), input_shape=(image_size[0], image_size[1], 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None))
model.add(Dropout(0.5))
model.add(Conv2D(32, kernel_size=(1,1), padding='valid', activation='relu'))
model.add(GlobalAveragePooling2D())
# model.add(Flatten())
model.add(Dense(len(species), activation='softmax'))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 96)      2688
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1552
#
#  conv2d_2 (Conv2D)           (None, 74, 74, 64)        1088
#
#  conv2d_3 (Conv2D)           (None, 74, 74, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 32)        2080
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       4224
#
#  conv2d_6 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 18, 18, 48)        6192
#
#  conv2d_8 (Conv2D)           (None, 18, 18, 192)       9408
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 192)       331968
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 192)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 9, 9, 64)          12352
#
#  conv2d_11 (Conv2D)          (None, 9, 9, 256)         16640
#
#  conv2d_12 (Conv2D)          (None, 9, 9, 256)         590080
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 32)          8224
#
#  global_average_pooling2d (G  (None, 32)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 65)                2145
#
# =================================================================
# Total params: 1,173,153
# Trainable params: 1,173,153
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Setting epochs and fitting the model

# %%
epochs=50

# %%
result = model.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=300) #batch_size=1
# Out:
# Epoch 1/50
# 4929/4929 [==============================] - 385s 76ms/step - loss: 3.3965 - accuracy: 0.1561 - val_loss: 2.8834 - val_accuracy: 0.2652
# Epoch 2/50
# 4929/4929 [==============================] - 371s 75ms/step - loss: 2.6964 - accuracy: 0.3026 - val_loss: 2.4571 - val_accuracy: 0.3507
# Epoch 3/50
# 4929/4929 [==============================] - 371s 75ms/step - loss: 2.3527 - accuracy: 0.3771 - val_loss: 2.1992 - val_accuracy: 0.4085
# Epoch 4/50
# 4929/4929 [==============================] - 371s 75ms/step - loss: 2.1781 - accuracy: 0.4174 - val_loss: 2.0721 - val_accuracy: 0.4411
# Epoch 5/50
# 4929/4929 [==============================] - 372s 75ms/step - loss: 2.0695 - accuracy: 0.4418 - val_loss: 1.9809 - val_accuracy: 0.4649
# Epoch 6/50
# 4929/4929 [==============================] - 372s 75ms/step - loss: 1.9894 - accuracy: 0.4615 - val_loss: 1.9000 - val_accuracy: 0.4870
# Epoch 7/50
# 4929/4929 [==============================] - 372s 75ms/step - loss: 1.9293 - accuracy: 0.4776 - val_loss: 1.8613 - val_accuracy: 0.4943
# Epoch 8/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.8759 - accuracy: 0.4880 - val_loss: 1.8696 - val_accuracy: 0.4934
# Epoch 9/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.8359 - accuracy: 0.4990 - val_loss: 1.8433 - val_accuracy: 0.4998
# Epoch 10/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.8058 - accuracy: 0.5069 - val_loss: 1.7826 - val_accuracy: 0.5164
# Epoch 11/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.7870 - accuracy: 0.5120 - val_loss: 1.8092 - val_accuracy: 0.5101
# Epoch 12/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.7623 - accuracy: 0.5160 - val_loss: 1.7340 - val_accuracy: 0.5295
# Epoch 13/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.7286 - accuracy: 0.5265 - val_loss: 1.7744 - val_accuracy: 0.5157
# Epoch 14/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.7178 - accuracy: 0.5287 - val_loss: 1.7004 - val_accuracy: 0.5358
# Epoch 15/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6935 - accuracy: 0.5342 - val_loss: 1.7092 - val_accuracy: 0.5358
# Epoch 16/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6801 - accuracy: 0.5368 - val_loss: 1.6953 - val_accuracy: 0.5341
# Epoch 17/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6682 - accuracy: 0.5409 - val_loss: 1.6526 - val_accuracy: 0.5434
# Epoch 18/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6507 - accuracy: 0.5442 - val_loss: 1.7832 - val_accuracy: 0.5107
# Epoch 19/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6413 - accuracy: 0.5468 - val_loss: 1.6260 - val_accuracy: 0.5525
# Epoch 20/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6349 - accuracy: 0.5472 - val_loss: 1.5968 - val_accuracy: 0.5619
# Epoch 21/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.6285 - accuracy: 0.5507 - val_loss: 1.6128 - val_accuracy: 0.5589
# Epoch 22/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6072 - accuracy: 0.5552 - val_loss: 1.6251 - val_accuracy: 0.5531
# Epoch 23/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.6034 - accuracy: 0.5559 - val_loss: 1.6100 - val_accuracy: 0.5616
# Epoch 24/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5952 - accuracy: 0.5588 - val_loss: 1.6402 - val_accuracy: 0.5493
# Epoch 25/50
# 4929/4929 [==============================] - 370s 75ms/step - loss: 1.5873 - accuracy: 0.5597 - val_loss: 1.5564 - val_accuracy: 0.5712
# Epoch 26/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5789 - accuracy: 0.5630 - val_loss: 1.6089 - val_accuracy: 0.5583
# Epoch 27/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5764 - accuracy: 0.5642 - val_loss: 1.5161 - val_accuracy: 0.5798
# Epoch 28/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5599 - accuracy: 0.5672 - val_loss: 1.5395 - val_accuracy: 0.5751
# Epoch 29/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5543 - accuracy: 0.5683 - val_loss: 1.5446 - val_accuracy: 0.5714
# Epoch 30/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5557 - accuracy: 0.5668 - val_loss: 1.5774 - val_accuracy: 0.5672
# Epoch 31/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5433 - accuracy: 0.5719 - val_loss: 1.5504 - val_accuracy: 0.5681
# Epoch 32/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5287 - accuracy: 0.5745 - val_loss: 1.5481 - val_accuracy: 0.5711
# Epoch 33/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5372 - accuracy: 0.5735 - val_loss: 1.5487 - val_accuracy: 0.5742
# Epoch 34/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5260 - accuracy: 0.5755 - val_loss: 1.4987 - val_accuracy: 0.5856
# Epoch 35/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5179 - accuracy: 0.5780 - val_loss: 1.5304 - val_accuracy: 0.5803
# Epoch 36/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.5081 - accuracy: 0.5790 - val_loss: 1.5855 - val_accuracy: 0.5614
# Epoch 37/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4942 - accuracy: 0.5815 - val_loss: 1.6198 - val_accuracy: 0.5541
# Epoch 38/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4914 - accuracy: 0.5845 - val_loss: 1.5618 - val_accuracy: 0.5680
# Epoch 39/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4880 - accuracy: 0.5856 - val_loss: 1.5375 - val_accuracy: 0.5730
# Epoch 40/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4937 - accuracy: 0.5840 - val_loss: 1.5098 - val_accuracy: 0.5834
# Epoch 41/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4767 - accuracy: 0.5887 - val_loss: 1.5440 - val_accuracy: 0.5774
# Epoch 42/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4677 - accuracy: 0.5904 - val_loss: 1.4625 - val_accuracy: 0.5959
# Epoch 43/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4566 - accuracy: 0.5924 - val_loss: 1.4520 - val_accuracy: 0.5967
# Epoch 44/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4567 - accuracy: 0.5919 - val_loss: 1.6012 - val_accuracy: 0.5604
# Epoch 45/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4703 - accuracy: 0.5903 - val_loss: 1.5058 - val_accuracy: 0.5836
# Epoch 46/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4584 - accuracy: 0.5917 - val_loss: 1.4774 - val_accuracy: 0.5982
# Epoch 47/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4439 - accuracy: 0.5962 - val_loss: 1.5405 - val_accuracy: 0.5762
# Epoch 48/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4442 - accuracy: 0.5950 - val_loss: 1.5240 - val_accuracy: 0.5786
# Epoch 49/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4352 - accuracy: 0.5987 - val_loss: 1.5071 - val_accuracy: 0.5859
# Epoch 50/50
# 4929/4929 [==============================] - 369s 75ms/step - loss: 1.4323 - accuracy: 0.5978 - val_loss: 1.4995 - val_accuracy: 0.5822

# %% [markdown]
# # Graph of loss change and accuracy change on train and val datasets

# %%
history = result

acc_train = history.history['accuracy']
acc_val = history.history['val_accuracy']
loss_train = history.history['loss']
loss_val = history.history['val_loss']

plt.figure(figsize=(17, 2))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc_train, label='Train data')
plt.plot(range(epochs), acc_val, label='Validation data')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss_train, label='Train data')
plt.plot(range(epochs), loss_val, label='Validation data')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# %%
scores = model.evaluate(val_ds, verbose=0)
print('Val loss:', scores[0])
print('Val accuracy:', scores[1])
# Out:
# Val loss: 1.4994765520095825
# Val accuracy: 0.5822157263755798

# %%
predictions = model.predict(test_ds)
#print('Predictions:\n', predictions.numpy())

# %%
print('Predictions:\n', predictions[np.argmax(tf.nn.softmax(predictions[0]))])
test_scores = model.evaluate(test_ds, verbose=0)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
# Out:
# Predictions:
#  [8.7938004e-04 3.6754872e-04 7.3753479e-05 3.2112775e-03 6.9519486e-03
#  5.8945060e-02 4.7168043e-03 2.1453541e-04 7.6438445e-03 1.6677853e-02
#  3.3914775e-04 2.7331840e-05 1.3684962e-03 1.0360043e-03 3.3710949e-02
#  4.5278241e-04 7.6554215e-06 2.4645913e-03 2.7217446e-02 4.8942570e-02
#  9.0242235e-04 3.8133044e-04 2.9042438e-03 8.4010110e-04 5.5847369e-04
#  3.8817976e-05 9.9415286e-04 1.4855623e-03 4.4487329e-04 6.0390558e-02
#  2.0045273e-02 4.4840952e-05 2.0180326e-03 9.3223397e-03 1.3913022e-04
#  4.9887281e-03 5.7459050e-03 5.0002860e-04 4.2707041e-02 1.3725781e-04
#  1.7246896e-02 2.0902643e-01 1.0544143e-02 1.8989075e-03 2.2436081e-02
#  7.9995650e-04 4.1306706e-04 2.2481769e-01 2.1731781e-05 1.2785993e-02
#  2.5694557e-03 8.3135196e-04 4.1477433e-03 3.1571329e-02 7.8310177e-04
#  6.8427849e-04 3.4501937e-03 1.8757054e-03 2.9663088e-05 1.1350341e-03
#  6.3895863e-03 2.2202086e-02 5.1414687e-02 8.9835601e-05 2.9970072e-03]
# Test loss: 1.49494469165802
# Test accuracy: 0.5850756764411926

# %% [markdown]
# # Saving the model
# Firstly we save it in the default format and then the HDF5 format.

# %%
model_version = 'squeezenet_0.1.1'

# %%
model.save('./exported_models/v'+model_version+'/botaniai_model_'+model_version+'.keras')

# %%
model.save('./exported_models/v'+model_version+'/botaniai_model_'+model_version+'.h5', save_format='h5')

# %%
model_json = model.to_json()
with open('./exported_models/v'+model_version+'/botaniai_model_'+model_version+'.json', "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights('./exported_models/v'+model_version+'/botaniai_model_weights_'+model_version+'.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # Convert model to tensorflow.js format

# %%
tfjs.converters.save_keras_model(model, './tensorflowjs/v'+model_version+'/')
